# %%
t=(10,203,48)
print(t[2])
# Out:
# 48

# %%
t=(10,20,47,92,10,3,48)
print(t[2:6])
# Out:
# (47, 92, 10, 3)

# %%
t=(10,20,47,92,10,3,48)
print(t[6:1:-2])
# Out:
# (48, 10, 47)

# %%
t=(10,20,47,92,10,3,48)
print(t[2:6:2])
# Out:
# (47, 10)

# %%
t=(10,20,47,92,10,3,48)
print(t[ :5])
# Out:
# (10, 20, 47, 92, 10)

# %%
t=(10,20,47,92,10,3,48)
print(t[4: ])
# Out:
# (10, 3, 48)

# %%
t=(10,20,47,92,10,3,48)
print(t[::-1 ])
# Out:
# (48, 3, 10, 92, 47, 20, 10)

# %%
t=(10,20,47,92,10,3,48)
print(t[::-2])
# Out:
# (48, 10, 47, 10)

# %%
t=(10,20,47,92,10,3,48)
t[2]=15
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4114840986.py in <cell line: 0>()
#       1 t=(10,20,47,92,10,3,48)
# ----> 2 t[2]=15
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(10,20,47,92,10,3,48,10)
print(t.count(10))
# Out:
# 3

# %%
t=(10,20,47,92,10,3,48,10)
print(t.index(10))
# Out:
# 0

# %%
t=(10,20,47,92,10,3,48,10)
print(t.index(10,2))
# Out:
# 4

# %%
t=(10,20,47,92,10,3,48,10)
print(t.index(10,5))
# Out:
# 7

# %%
t=10,'chaithu',2780.88
print(t)
type(t)
# Out:
# (10, 'chaithu', 2780.88)
# tuple

# %%
num,name,val=t
print(num)
print(name)
print(val)
# Out:
# 10
# chaithu
# 2780.88
