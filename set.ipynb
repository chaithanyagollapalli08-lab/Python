# %%
s={10,12.56,'chaithu',(1,2,3)}
print(s)
# Out:
# {10, 'chaithu', 12.56, (1, 2, 3)}

# %%
s={10,12.56,'chaithu',[10]}# set is mutable,but inside the set it doesn't allow mutable
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3306456997.py in <cell line: 0>()
# ----> 1 s={10,12.56,'chaithu',[10]}
#       2 print(s)
#
# TypeError: unhashable type: 'list'

# %%
s={10,12.56,'chaithu',{1,2}}#set in set also not allowed
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1918590326.py in <cell line: 0>()
# ----> 1 s={10,12.56,'chaithu',{1,2}}
#       2 print(s)
#
# TypeError: unhashable type: 'set'

# %%
s={10,20,30,'abc'}
s.add(50)
print(s)
# Out:
# {'abc', 10, 50, 20, 30}

# %%
s={10,20,30,'abc'}
s.update([50,100,287])
print(s)
# Out:
# {100, 'abc', 10, 50, 20, 30, 287}

# %%
s={10,20,30,'abc'}
s.discard('abc')
print(s)
# Out:
# {10, 20, 30}

# %%
s={10,20,30,'abc'}
s.discard(40)
print(s)
# Out:
# {10, 20, 30, 'abc'}

# %%
s={10,20,30,'abc'}
s.remove(30)
print(s)
# Out:
# {10, 20, 'abc'}

# %%
s={10,20,30,'abc'}
s.remove(40)
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3367567872.py in <cell line: 0>()
#       1 s={10,20,30,'abc'}
# ----> 2 s.remove(40)
#       3 print(s)
#
# KeyError: 40

# %%
s={10,20,30,'abc'}
s.clear()
print(s)
# Out:
# set()

# %%
s={10,20,30,'abc'}
b=s
print(s)
print(b)
s.add(40)
print(s)
print(b)
# Out:
# {10, 20, 30, 'abc'}
# {10, 20, 30, 'abc'}
# {'abc', 40, 10, 20, 30}
# {'abc', 40, 10, 20, 30}

# %%
s={10,20,30,'abc'}
b=s.copy()
print(s)
print(b)
s.add(40)
print(s)
print(b)
# Out:
# {10, 20, 30, 'abc'}
# {10, 20, 30, 'abc'}
# {'abc', 40, 10, 20, 30}
# {10, 20, 30, 'abc'}

# %%
r=set()
r.add(10)
r.add(20)
print(r)
# Out:
# {10, 20}

# %%
a={10,20,30,'abe'}
b={50,'cde'}
print(a|b)
print(a.union(b))
# Out:
# {'abe', 'cde', 50, 20, 10, 30}
# {'abe', 'cde', 50, 20, 10, 30}

# %%
a={10,20,30,'abe'}
b={50,'cde'}
print(a|b)
print(a.union(b))

# %%
a={10,20,30,'abe'}
b={50,'cde',20,30}
print(a&b)
print(a.intersection(b))
# Out:
# {20, 30}
# {20, 30}

# %%
a={10,20,30,'abe'}
b={50,'cde',20,30}
print(a-b)
print(a.difference(b))
# Out:
# {'abe', 10}
# {'abe', 10}

# %%
a={10,20,30,'abe'}
b={50,'cde'}
print(a^b)
print(a.symmetric_difference(b))
# Out:
# {10, 'abe', 'cde', 50, 20, 30}
# {10, 'abe', 'cde', 50, 20, 30}

# %%
a={10,20,30,'abe'}
b={50,'cde',20,30}
print(a.isdisjoint(b))
# Out:
# False

# %%
a={10,20,30,'abe'}
b={50,'cde',20,30}
print(a.issuperset(b))
# Out:
# False

# %%
a={10,20,30,'abe'}
b={50,'cde',20,30}
print(a.issubset(b))
# Out:
# False

# %%
a={10,20,20,30,'abe'}
print(a)
# Out:
# {'abe', 10, 20, 30}
