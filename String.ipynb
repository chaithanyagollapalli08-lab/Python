# %%
a='chaithanya'
print(a)
# Out:
# chaithanya

# %%
a='chaithanya'
print(a[0])
print(a[5])
print(a[9])
# Out:
# c
# h
# a

# %%
a='chaithanya'
print(a[-5])
# Out:
# h

# %%
a='chaithanya'
print(a[0]+a[5]+a[7]+a[-2])
# Out:
# chny

# %%
a='chaithanya'
print( a*3)
# Out:
# chaithanyachaithanyachaithanya

# %%
a='chaithanya'
print(a[1:7])
# Out:
# haitha

# %%
a='chaithanya'
print(a[6:-3])
# Out:
# a

# %%
a='chaithanya'
print(a[-7:5])
# Out:
# it

# %%
print(a[ :6])
# Out:
# chaith

# %%
print(a[6: ])
# Out:
# anya

# %%
print(a[:: -1])
# Out:
# aynahtiahc

# %%
a='chaithanya'
print(a[-7:5])
# Out:
# hihn

# %%
a='chaithanya'
print(a[8:2:-2])
# Out:
# yat

# %%
a='chaithanya'
a[4]='p'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3856143364.py in <cell line: 0>()
#       1 a='chaithanya'
# ----> 2 a[4]='p'
#
# TypeError: 'str' object does not support item assignment

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
#capitalize
d='cHAIthaNyA'
print(d.capitalize())
# Out:
# Chaithanya

# %%
#title
d='chaithu chaithanya'
print(d.title())
# Out:
# Chaithu Chaithanya

# %%
#lower
d='cHAIthaNyA'
print(d.islower())
# Out:
# False

# %%
d='cHAIthaNyA'
print(d.lower())
# Out:
# chaithanya

# %%
d='cHAIthaNyA'
print(d.isupper())
# Out:
# False

# %%
d='cHAIthaNyA'
print(d.upper())
# Out:
# CHAITHANYA

# %%
d='ABC'
print(d.isupper())
# Out:
# True

# %%
d='cHAIthaNyA'
print(d.isalpha())
# Out:
# True

# %%
d='cHAIth aNyA'
print(d.isalpha())
# Out:
# False

# %%
e='123'
print(e.isnumeric())
# Out:
# True

# %%
e='123.89'
print(e.isnumeric())
# Out:
# False

# %%
e='123'
print(e.isalnum())
# Out:
# True

# %%
e='abc'
print(e.isalnum())
# Out:
# True

# %%
e='abc12'
print(e.isalnum())
# Out:
# True

# %%
a='chaithanya'
print(a.find('a',3))
# Out:
# 6

# %%
a='chaithanya'
print(a.startswith('a'))
# Out:
# False

# %%
a='chaithanya'
print(a.startswith('c'))
# Out:
# True

# %%
a='chaithanya'
print(a.endswith('c'))
# Out:
# False

# %%
a='chaithanya'
print(a.replace('a','n'))
# Out:
# chnithnnyn

# %%
a='chaithanya'
print(a.replace('a','n',1))
# Out:
# chnithanya

# %%
a='chaithanya'#want to replace third a
print(a.index('a',8))
# Out:
# 9

# %%
a='chaithanya'#want to replace third a
start=a[ :a.index('a',8)]
end=a[a.index('a',8): ]
end=end.replace('a','n')
print(start+end)
# Out:
# chaithanyn

# %%
a='chaithanya'
print(a.count('a'))
# Out:
# 3

# %%
a='chaithanya'
print('c' in a)
print('l' in a)
print('l' not in a)
# Out:
# True
# False
# True

# %%
ord('a')
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'

# %%
a='chaithu'
for i in a:
  print(i,ord(i))
# Out:
# c 99
# h 104
# a 97
# i 105
# t 116
# h 104
# u 117
