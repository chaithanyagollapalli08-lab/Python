# %%
l=[19,30,49,46,29,68,74]
print(l[6])
# Out:
# 74

# %%
l=[19,30,49,46,29,68,74]
print(l[2:6])
# Out:
# [49, 46, 29, 68]

# %%
l=[19,30,49,46,29,68,74]
print(l[6:2:-2])
# Out:
# [74, 29]

# %%
l=[19,30,49,46,29,68,74]
print(l[1:5:2])
# Out:
# [30, 46]

# %%
l=[19,30,49,46,29,68,74]
print(l[::-1])
# Out:
# [74, 68, 29, 46, 49, 30, 19]

# %%
l=[19,30,49,46,29,68,74]
l.append(20)
print(l)
# Out:
# [19, 30, 49, 46, 29, 68, 74, 20]

# %%
a=[10,39,48,75,92]
a.extend([20,40])
print(a)
# Out:
# [10, 39, 48, 75, 92, 20, 40]

# %%
a=[10,39,48,75,92]
a.insert(2,90)
print(a)
# Out:
# [10, 39, 90, 48, 75, 92]

# %%
a=[10,39,48,75,92]
a.pop()
print(a)
# Out:
# [10, 39, 48, 75]

# %%
a=[10,39,48,75,92]
a.pop(4)
print(a)
# Out:
# [10, 39, 48, 75]

# %%
a=[10,39,48,75,92]
a.remove(48)
print(a)
# Out:
# [10, 39, 75, 92]

# %%
a=[10,39,48,75,92]
print(a.index(48))
# Out:
# 2

# %%
a=[10,39,48,75,92]
print(a.count(48))
# Out:
# 1

# %%
a=[10,39,48,75,92]
a.clear()
print(a)
# Out:
# []

# %%
l=[19,30,49,46,29,68,74]
l.sort()
print(l)
# Out:
# [19, 29, 30, 46, 49, 68, 74]

# %%
l=[19,30,49,46,29,68,74]
l.sort(reverse=True)
print(l)
# Out:
# [74, 68, 49, 46, 30, 29, 19]

# %%
l=[19,30,49,46,29,68,74]
l.reverse()
print(l)
# Out:
# [74, 68, 29, 46, 49, 30, 19]

# %%
a=[10,20,30]
b=a
print(a)
print(b)
a.append(50)
print(a)
print(b)
# Out:
# [10, 20, 30]
# [10, 20, 30]
# [10, 20, 30, 50]
# [10, 20, 30, 50]

# %%
a=[10,20,30]
b=a.copy()
print(a)
print(b)
a.append(50)
print(a)
print(b)
# Out:
# [10, 20, 30]
# [10, 20, 30]
# [10, 20, 30, 50]
# [10, 20, 30]
