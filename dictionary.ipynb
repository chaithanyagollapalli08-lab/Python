# %%
d={'a':100,'b':200,'c':300}
print(d)
print(type(d))
# Out:
# {'a': 100, 'b': 200, 'c': 300}
# <class 'dict'>

# %%
d={'a':100,'b':200,'c':300}
print(d['a'])
# Out:
# 100

# %%
d={'name':['chaithu','saritha','abhi'],
   'age':[22,21,20],
    'salary':[10000,15000,20000]
}
print(d['name'])
# Out:
# ['chaithu', 'saritha', 'abhi']

# %%
d={'name':['chaithu','saritha','abhi'],
   'age':[22,21,20],
    'salary':[10000,15000,20000]
}
print(d['name'][2])
# Out:
# abhi

# %%
import pandas as pd
pd.DataFrame(d)
# Out:
#       name  age  salary
# 0  chaithu   22   10000
# 1  saritha   21   15000
# 2     abhi   20   20000

# %%
d={'name':['chaithu','saritha','abhi'],
   'age':[22,21,20],
    'salary':[10000,15000,20000]
}
print(d['name'][ :2])
# Out:
# ['chaithu', 'saritha']

# %%
d={'a':1,[1,2,3]:20}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2328826424.py in <cell line: 0>()
# ----> 1 d={'a':1,[1,2,3]:20}
#
# TypeError: unhashable type: 'list'

# %%
d={'a':100,'b':200,'c':300}
d['a']=500 #update
print(d)
# Out:
# {'a': 500, 'b': 200, 'c': 300}

# %%
d={'a':100,'b':200,'c':300}
d['e']=500 #adding
print(d)
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'e': 500}

# %%
d={'a':100,'b':200,'c':300}
del d['a']
print(d)
# Out:
# {'b': 200, 'c': 300}

# %%
d={'name':['chaithu','saritha','abhi'],
   'age':[22,21,20],
    'salary':[10000,15000,20000]
}
print(d.get('age'))
print(d['age'])
# Out:
# [22, 21, 20]
# [22, 21, 20]

# %%
a={'apple':100,'banana':200,'carrot':300}
a.update({'guava':600})
print(a)
# Out:
# {'apple': 100, 'banana': 200, 'carrot': 300, 'guava': 600}

# %%
a={'apple':100,'banana':200,'carrot':300}
a.pop('banana')
print(a)
# Out:
# {'apple': 100, 'carrot': 300}

# %%
a={'apple':100,'banana':200,'carrot':300}
a.popitem()
print(a)
# Out:
# {'apple': 100, 'banana': 200}

# %%
a={'apple':100,'banana':200,'carrot':300}

print(a.keys())
# Out:
# dict_keys(['apple', 'banana', 'carrot'])

# %%
a={'apple':100,'banana':200,'carrot':300}

print(a.values())
# Out:
# dict_values([100, 200, 300])

# %%
a={'apple':100,'banana':200,'carrot':300}

print(a.items())
# Out:
# dict_items([('apple', 100), ('banana', 200), ('carrot', 300)])

# %%
a={'apple':100,'banana':200,'carrot':300}
b=a
print(a)
print(b)
a.update({'kiwi':400})
print(a)
print(b)
# Out:
# {'apple': 100, 'banana': 200, 'carrot': 300}
# {'apple': 100, 'banana': 200, 'carrot': 300}
# {'apple': 100, 'banana': 200, 'carrot': 300, 'kiwi': 400}
# {'apple': 100, 'banana': 200, 'carrot': 300, 'kiwi': 400}

# %%
a={'apple':100,'banana':200,'carrot':300}
b=a.copy()
print(a)
print(b)
a.update({'kiwi':400})
print(a)
print(b)
# Out:
# {'apple': 100, 'banana': 200, 'carrot': 300}
# {'apple': 100, 'banana': 200, 'carrot': 300}
# {'apple': 100, 'banana': 200, 'carrot': 300, 'kiwi': 400}
# {'apple': 100, 'banana': 200, 'carrot': 300}

# %%
a={'apple':100,'banana':200,'carrot':300}
a.clear()
print(a)
# Out:
# {}

# %%
a={'apple':100,'banana':200,'carrot':300}
print('apple' in a)
print(100 in a) #100 is not a key
# Out:
# True
# False

# %%
d=dict()
print(d)
# Out:
# {}

# %%
d=dict([('a',1),('b',2)])
print(d)
# Out:
# {'a': 1, 'b': 2}
